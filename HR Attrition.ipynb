# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

# %%
attrition = pd.read_csv('Final dataset Attrition.csv')

# %%
attrition.plot('Age')
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-10737f9bc146> in <module>
# ----> 1 attrition.value_counts(sort('Age'))
#
# NameError: name 'sort' is not defined
